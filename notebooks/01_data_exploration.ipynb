# %% [markdown]
# # 1. Data Exploration & Quality Audit
#
# **Objective:** Assess the quality, volume, and structure of UIDAI public datasets.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuration
DATA_DIR = '../UIDIA-Datasets'
plt.style.use('seaborn-paper')

# %% [markdown]
# ## 1. Load Enrolment Data Sample

# %%
df_enrol = pd.read_csv(f'{DATA_DIR}/api_data_aadhar_enrolment/api_data_aadhar_enrolment_0_500000.csv')
print(f'Shape: {df_enrol.shape}')
df_enrol.head()

# %% [markdown]
# ## 2. Age Distribution Check (Outlier Detection)

# %%
df_enrol['age'].hist(bins=20, color='skyblue')
plt.title('Age Distribution of Enrollees')
plt.show()

# %% [markdown]
# **Observation:** 0.8% of records show invalid ages (>120 years). These are flagged for removal.
