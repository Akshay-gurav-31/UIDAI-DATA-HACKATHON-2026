# %% [markdown]
# # 4. Process Synchronization (Correlation Study)
#
# **Hypothesis:** Disparate administrative processes are artificially coupled.

# %%
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ## 1. Pearson Correlation Analysis

# %%
r, p = stats.pearsonr(daily['child_updates'], daily['adult_updates'])
print(f'Pearson r: {r:.4f}, p-value: {p:.4e}')

# %%
sns.regplot(x='child_updates', y='adult_updates', data=daily)
plt.title('Child vs Adult Update Volume')
